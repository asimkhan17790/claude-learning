# %%
# Install Dependencies

# %pip install anthropic python-dotenv

# %%
#Load Environment Variables

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#  Create an API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Make a request

def add_user_message(messages, text):
    user_message = {
        "role":"user",
        "content": text
    } 
    messages.append(user_message)
def add_assistant_message(messages, text):
    assistant_message = {
        "role":"assistant",
        "content": text
    } 
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []


# Add in the initial user question
add_user_message(messages, "What is the Quantum Computing ?")



#Pass the list of messages into the chat to get an answer
answer = chat(messages)



#Take the answer and add it s an assistant message into our list
add_assistant_message(messages, answer)
messages

# Add in the user's followup question

add_user_message(messages, "Write another Sentence!")

# Call the chat again with the list of messages to get the final answer
answer = chat(messages)

print(answer)
# Out:
# Quantum computing represents one of the most exciting frontiers in technology, where the strange and counterintuitive laws of quantum physics are being harnessed to create machines that could one day solve problems currently considered impossible for even the most powerful supercomputers.
